# %%
import matplotlib
from mpl_toolkits import mplot3d
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import os

# %%
path=os.environ["userprofile"]+"\\"+".atom"+"\\"+"Transactions.csv"
print(path)
# Out:
# C:\Users\657432343536\.atom\Transactions.csv

# %%
data = pd.read_csv(path)
print(data)
# Out:
#       Date_and_time_of_unloading  Product_code  Amount  Sale_amount  \
# 0            2020-01-01 23:00:00           144     1.0       280.00
# 1            2020-01-01 23:00:00           209     2.0       545.73
# 2            2020-01-01 23:00:00           213     2.0      1265.05
# 3            2020-01-01 23:00:00           217     1.0       630.00
# 4            2020-01-01 23:00:00           222     2.0      1104.75
# ...                          ...           ...     ...          ...
# 50079        2022-09-18 15:00:00          5316     6.0      1875.95
# 50080        2022-09-18 15:00:00          5317     2.0       555.95
# 50081        2022-09-18 15:00:00          5318     2.0       572.50
# 50082        2022-09-18 15:00:00          5321     1.0       300.00
# 50083        2022-09-18 15:00:00          5322     2.0       600.00
#
#        Discount_amount   Profit  Percentage_markup  Discount_percentage
# 0                  NaN   155.00             124.00                  NaN
# 1               294.27    75.73              16.11                35.03
# 2                34.95   653.05             106.71                 2.69
# 3                70.00   220.50              53.85                10.00
# 4               195.25   393.75              55.38                15.02
# ...                ...      ...                ...                  ...
# 50079           104.05  1095.95             140.51                 5.26
# 50080           104.05   315.95             131.65                15.77
# 50081            87.50   312.50             120.19                13.26
# 50082              NaN   180.00             150.00                  NaN
# 50083              NaN   340.00             130.77                  NaN
#
# [50084 rows x 8 columns]

# %%
data.plot.area()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 data.plot.area()
#
# File c:\users\657432343536\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_core.py:1473, in PlotAccessor.area(self, x, y, **kwargs)
#    1402 def area(self, x=None, y=None, **kwargs):
#    1403     """
#    1404     Draw a stacked area plot.
#    1405
#    (...)
#    1471         >>> ax = df.plot.area(x='day')
#    1472     """
# -> 1473     return self(kind="area", x=x, y=y, **kwargs)
#
# File c:\users\657432343536\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_core.py:949, in PlotAccessor.__call__(self, *args, **kwargs)
#     946             label_name = label_kw or data.columns
#     947             data.columns = label_name
# --> 949 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\users\657432343536\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:61, in plot(data, kind, **kwargs)
#      59         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61 plot_obj.generate()
#      62 plot_obj.draw()
#      63 return plot_obj.result
#
# File c:\users\657432343536\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:271, in MPLPlot.generate(self)
#     269 self._compute_plot_data()
#     270 self._setup_subplots()
# --> 271 self._make_plot()
#     272 self._add_table()
#     273 self._make_legend()
#
# File c:\users\657432343536\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:1118, in LinePlot._make_plot(self)
#    1115 label = pprint_thing(label)  # .encode('utf-8')
#    1116 kwds["label"] = label
# -> 1118 newlines = plotf(
#    1119     ax,
#    1120     x,
#    1121     y,
#    1122     style=style,
#    1123     column_num=i,
#    1124     stacking_id=stacking_id,
#    1125     is_errorbar=is_errorbar,
#    1126     **kwds,
#    1127 )
#    1128 self._add_legend_handle(newlines[0], label, index=i)
#    1130 if self._is_ts_plot():
#    1131
#    1132     # reset of xlim should be used for ts data
#    1133     # TODO: GH28021, should find a way to change view limit on xaxis
#
# File c:\users\657432343536\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:1288, in AreaPlot._plot(cls, ax, x, y, style, column_num, stacking_id, is_errorbar, **kwds)
#    1286 if column_num == 0:
#    1287     cls._initialize_stacker(ax, stacking_id, len(y))
# -> 1288 y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
#    1290 # need to remove label, because subplots uses mpl legend as it is
#    1291 line_kwds = kwds.copy()
#
# File c:\users\657432343536\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:1206, in LinePlot._get_stacked_values(cls, ax, stacking_id, values, label)
#    1203 elif (values <= 0).all():
#    1204     return ax._stacker_neg_prior[stacking_id] + values
# -> 1206 raise ValueError(
#    1207     "When stacked is True, each column must be either "
#    1208     "all positive or negative."
#    1209     f"{label} contains both positive and negative values"
#    1210 )
#
# ValueError: When stacked is True, each column must be either all positive or negative.Profit contains both positive and negative values

# %%
plt.fill_between(data["Product_code"][:50], data["Profit"][:50])

plt.show()

# %%
plt.scatter(data["Product_code"][:5000], data["Profit"][:5000])
plt.show()

# %%
sns.heatmap(data.corr(), xticklabels=data.corr().columns,
            yticklabels=data.corr().columns,
            cmap='turbo',
            center=0,
            annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(data["Profit"], hist=True, kde=False, rug=False )
# Out:
# C:\Users\657432343536\AppData\Local\Temp\ipykernel_16084\1452918687.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Profit"], hist=True, kde=False, rug=False )
# <AxesSubplot:xlabel='Profit'>

# %%
zuh=[data["Profit"][:50],data["Sale_amount"][:50],data["Discount_amount"][:50]]
sns.violinplot(zuh)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=data[:500], legend=False, sizes=(20, 2000))
# Out:
# <AxesSubplot:>
